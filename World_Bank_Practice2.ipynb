# %%
ls
# Out:
# API_SP.DYN.LE00.IN_DS2_en_csv_v2_10134486.csv  World Bank Life Expectancy.ipynb
# nees@                                          World_Bank_Practice2.ipynb

# %%
! pwd
# Out:
# /home/jupyter/practice_TACC

# %%
ls home
# Out:
# ls: cannot access 'home': No such file or directory

# %%
ls TACC-practice
# Out:
# ls: cannot access 'TACC-practice': No such file or directory

# %%
ls practice_TACC
# Out:
# ls: cannot access 'practice_TACC': No such file or directory

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# %%
! head /home/jupyter/practice_TACC/API_SP.DYN.LE00.IN_DS2_en_csv_v2_10134486.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2018-09-21",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
# ...

# %%
df=pd.read_csv("/home/jupyter/practice_TACC/API_SP.DYN.LE00.IN_DS2_en_csv_v2_10134486.csv", header=2, index_col=[0,1,2,3])
df.head()
# Out:
#                                                                                     1960  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  65.662
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.292
# Angola       AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  33.251
# Albania      ALB          Life expectancy at birth, total (years) SP.DYN.LE00.IN  62.279
# Andorra      AND          Life expectancy at birth, total (years) SP.DYN.LE00.IN     NaN
#
#                                                                                     1961  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  66.074
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.742
# ...

# %%
df['1998'].dropna()
# Out:
# Country Name                                          Country Code  Indicator Name                           Indicator Code
# Aruba                                                 ABW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    73.700000
# Afghanistan                                           AFG           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    54.468000
# Angola                                                AGO           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    45.192000
# Albania                                               ALB           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    73.208000
# Arab World                                            ARB           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    67.133268
# United Arab Emirates                                  ARE           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    73.732000
# ...

# %%
pd.read_csv()

# %%
df.plot()

# %%
df.groupby(level=0).first().transpose()
# Out:
# Country Name  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960               32.292   62.279   46.138             NaN      NaN  33.251
# 1961               32.742   63.298   46.596             NaN      NaN  33.573
# 1962               33.185   64.187   47.054             NaN      NaN  33.914
# 1963               33.624   64.911   47.507             NaN      NaN  34.272
# 1964               34.060   65.461   47.956             NaN      NaN  34.645
# 1965               34.495   65.848   48.392             NaN      NaN  35.031
# 1966               34.928   66.108   48.809             NaN      NaN  35.426
# 1967               35.361   66.302   49.208             NaN      NaN  35.828
# 1968               35.796   66.485   49.595             NaN      NaN  36.234
# 1969               36.234   66.687   49.980             NaN      NaN  36.640
# 1970               36.678   66.933   50.369             NaN      NaN  37.047
# ...

# %%
dfnew=df.groupby(level=0).first().transpose()
dfnewSubset= dfnew[['United States', 'Channel Islands']]
dfnewSubset.head()
dfnewSubset.plot()

# %% [markdown]
# #
